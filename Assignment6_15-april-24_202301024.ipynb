# %% [markdown]
# <a href="https://colab.research.google.com/github/JatinFulra/Big-Data/blob/main/Assignment6_15-april-24_202301024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([[1], [2], [3], [4], [5],[6],[7]])
y = np.array([9,8,10,12,11,13,14])

# Create and fit the model
model = LinearRegression()
model.fit(X, y)

# Get the coefficients
intercept = model.intercept_
slope = model.coef_[0]

# Predict
y_pred = model.predict(X)

# Plot
plt.scatter(X, , color='red')
plt.plot(X, y_pred, color='blue')
plt.xlabel('X')
plt.ylabel('y')
plt.title('SLR')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
